# %% [markdown]
# <a href="https://colab.research.google.com/github/GNeves92/Fonte-de-dados-/blob/main/Gr%C3%A1fico%20de%20dispers%C3%A3o%20e%20regress%C3%A3o%20linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv'
df = pd.read_csv(url)

print("DataFrame created successfully. Here are the first 5 rows:")
print(df.head())
# Out:
# DataFrame created successfully. Here are the first 5 rows:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Experience Years', y='Salary', data=df, label='Dados Originais')

# Get the predicted values from the trained model
y_pred = model.predict(X)

# Plot the regression line
plt.plot(X, y_pred, color='red', label='Linha de Regressão Linear')

plt.title('Gráfico de Dispersão com Linha de Regressão Linear')
plt.xlabel('Anos de Experiência')
plt.ylabel('Salário')
plt.grid(True)
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Prepare the data for the model
# The independent variable (Experience Years) needs to be reshaped for scikit-learn
X = df[['Experience Years']]
y = df['Salary']

# Create and train the linear regression model
model = LinearRegression()
model.fit(X, y)

# Print the model's coefficients and intercept
print(f"Coeficiente (inclinação): {model.coef_[0]:.2f}")
print(f"Intercepto: {model.intercept_:.2f}")
# Out:
# Coeficiente (inclinação): 9523.65
# Intercepto: 25673.02
